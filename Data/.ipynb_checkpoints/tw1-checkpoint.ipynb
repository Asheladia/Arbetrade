# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from tweepy) (1.10.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\mshel\anaconda3\envs\alpacaenv\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: tweepy
# Successfully installed tweepy-3.10.0

# %%
import tweepy as tw
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API

# %%
TWITTER_CONSUMER_KEY = "TWITTER_CONSUMER_KEY"
TWITTER_CONSUMER_SECRET_KEY = "TWITTER_CONSUMER_KEY_SECRET"
TWITTER_ACCESS_TOKEN = "TWITTER_ACCESS_TOKEN"
TWITTER_ACCESS_SECRET_TOKEN = "TWITTER_ACCESS_SECRET_TOKEN"

# %%
len("TWITTER_ACCESS_SECRET_TOKEN")
# Out:
# 27

# %%
# # # # TWITTER STREAMER # # # #
class TwitterStreamer():
    """
    Class for streaming and processing live tweets.
    """
    def __init__(self):
        pass

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        # This handles Twitter authetification and the connection to Twitter Streaming API
        listener = StdOutListener(fetched_tweets_filename)
        auth = OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET_KEY)
        auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_SECRET_TOKEN)
        stream = Stream(auth, listener)

        # This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=hash_tag_list)

# %%
# # # # TWITTER STREAM LISTENER # # # #
class StdOutListener(StreamListener):
    """
    This is a basic listener that just prints received tweets to stdout.
    """
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
          

    def on_error(self, status):
        print(status)

 
if __name__ == '__main__':
 
    # Authenticate using config.py and connect to Twitter Streaming API.
    hash_tag_list = ['S&P 500', 'Donald Trump', 'Jim Cramer','Jaime Dimon', 'Lloyd Blankfein', 'Michael Corbat', 'David Solomon']
    fetched_tweets_filename = "tweets.txt"

    twitter_streamer = TwitterStreamer()
    twitter_streamer.stream_tweets(fetched_tweets_filename, hash_tag_list)
# Out:
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
# 401
